# %%
# import dependencies
import pandas as pd

# Database dependencies
from sqlalchemy import create_engine
from config import username, db_password

# %%
#  create the database engine
db_string = f"postgresql://{username}:{db_password}@127.0.0.1:5432/FinalProject"
engine = create_engine(db_string)

# %%
# read in data
urban_population_df = pd.read_csv("resources/urban_populations.csv")
city_population_df = pd.read_csv("resources/city_populations.csv")
housing_df = pd.read_csv("resources/realtor-data.csv")

# %%
# preview data frames
urban_population_df.head()
# Out:
#            city population_2019 population_2020 population_2021  \
# 0  Mount Vernon          67,345          73,893          72,584
# 1  Mount Vernon          67,345          73,893          72,584
# 2  Mount Vernon          67,345          73,893          72,584
# 3  New Rochelle          78,557          79,726          81,590
# 4  New Rochelle          78,557          79,726          81,590
#
#                                              Sources
# 0  2019: https://www.city-data.com/city/Mount-Ver...
# 1  2020: https://www.census.gov/quickfacts/fact/t...
# 2  2021: https://censusreporter.org/profiles/1600...
# 3  2019: https://www.city-data.com/city/New-Roche...
# 4  2020: https://www.census.gov/quickfacts/fact/t...

# %%
city_population_df.head()
# Out:
#              city population_2019 population_2020 population_2021  \
# 0        Brooklyn       2,559,903       2,736,074       2,641,052
# 1           Bronx       1,418,207       1,472,654       1,424,948
# 2  Staten Island          476,143         495,747         493,494
# 3          Queens       2,253,858       2,405,464       2,331,143
# 4       Manhattan       1,628,706       1,694,251       1,576,876
#
#                                              Sources
# 0  NYC 2020 census-  https://popfactfinder.planni...
# 1  NYC 2019- https://www1.nyc.gov/assets/planning...
# 2  NYC 2021= http://www.citypopulation.de/en/usa/...
# 3                                                NaN
# 4                                                NaN

# %%
housing_df
# Out:
#           status     price  bed  bath  acre_lot  \
# 0       for_sale  105000.0  3.0   2.0      0.12
# 1       for_sale   80000.0  4.0   2.0      0.08
# 2       for_sale   67000.0  2.0   1.0      0.15
# 3       for_sale  145000.0  4.0   2.0      0.10
# 4       for_sale   65000.0  6.0   2.0      0.05
# ...          ...       ...  ...   ...       ...
# 923154  for_sale  445000.0  1.0   2.0      0.99
# 923155  for_sale  418000.0  4.0   2.0      0.40
# 923156  for_sale  469000.0  4.0   2.0      0.18
# 923157  for_sale  825000.0  5.0   5.0      0.79
# 923158  for_sale   88000.0  NaN   NaN     35.00
#
#                                              full_address  \
# 0       Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1                 Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2                 556G 556-G 16 St, Juana Diaz, PR, 00795
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                         14 Navarro, Mayaguez, PR, 00680
# ...                                                   ...
# 923154                 1008 King St, Chappaqua, NY, 10514
# 923155                    3 Elmwood Dr, Monroe, NY, 10950
# 923156                13 N Conger Ave, Congers, NY, 10920
# 923157             7 Miller Rd, Valley Cottage, NY, 10989
# 923158  D18 Half Moon Bay Dr, Croton On Hudson, NY, 10520
#
#                                                street              city  \
# 0                        Sector Yahuecas Titulo # V84          Adjuntas
# 1                                  Km 78 9 Carr # 135          Adjuntas
# 2                                    556G 556-G 16 St        Juana Diaz
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce             Ponce
# 4                                          14 Navarro          Mayaguez
# ...                                               ...               ...
# 923154                                   1008 King St         Chappaqua
# 923155                                   3 Elmwood Dr            Monroe
# 923156                                13 N Conger Ave           Congers
# 923157                                    7 Miller Rd    Valley Cottage
# 923158                           D18 Half Moon Bay Dr  Croton On Hudson
#
#               state  zip_code  house_size   sold_date
# 0       Puerto Rico     601.0       920.0         NaN
# 1       Puerto Rico     601.0      1527.0         NaN
# 2       Puerto Rico     795.0       748.0         NaN
# 3       Puerto Rico     731.0      1800.0         NaN
# 4       Puerto Rico     680.0         NaN         NaN
# ...             ...       ...         ...         ...
# 923154     New York   10514.0      1052.0  2011-05-09
# 923155     New York   10950.0      1650.0  2015-07-21
# 923156     New York   10920.0      2123.0         NaN
# 923157     New York   10989.0      3775.0  2010-06-02
# 923158     New York   10520.0       780.0         NaN
#
# [923159 rows x 12 columns]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Urban Population Data

# %%
# drop excess columns
urban_population_df = urban_population_df.drop(urban_population_df.columns[[4]], axis=1)

# %%
# drop rows with null values
urban_population_df = urban_population_df.drop_duplicates(subset=None, keep='first', inplace= False)

# %%
urban_population_df
# Out:
#             city population_2019 population_2020 population_2021
# 0   Mount Vernon          67,345          73,893          72,584
# 3   New Rochelle          78,557          79,726          81,590
# 6          Nyack           7,156           7,247           7,236
# 9       Tuckahoe           6,549           7,084           6,974
# 12       Suffern          11,007          11,441          11,402
# 15       Warwick           6,775           6,652           6,672
# 18   Stony Point          12,586          14,813          14,768
# 21     Scarsdale          17,871          18,253          17,939

# %% [markdown]
# #### City Population Data

# %%
# drop excess columns
city_population_df = city_population_df.drop(city_population_df.columns[[4]], axis=1)

# %%
# drop rows with null values
city_population_df = city_population_df.dropna()

# %%
city_population_df
# Out:
#              city population_2019 population_2020 population_2021
# 0        Brooklyn       2,559,903       2,736,074       2,641,052
# 1           Bronx       1,418,207       1,472,654       1,424,948
# 2  Staten Island          476,143         495,747         493,494
# 3          Queens       2,253,858       2,405,464       2,331,143
# 4       Manhattan       1,628,706       1,694,251       1,576,876

# %% [markdown]
# #### Housing Data

# %%
housing_df
# Out:
#           status     price  bed  bath  acre_lot  \
# 0       for_sale  105000.0  3.0   2.0      0.12
# 1       for_sale   80000.0  4.0   2.0      0.08
# 2       for_sale   67000.0  2.0   1.0      0.15
# 3       for_sale  145000.0  4.0   2.0      0.10
# 4       for_sale   65000.0  6.0   2.0      0.05
# ...          ...       ...  ...   ...       ...
# 923154  for_sale  445000.0  1.0   2.0      0.99
# 923155  for_sale  418000.0  4.0   2.0      0.40
# 923156  for_sale  469000.0  4.0   2.0      0.18
# 923157  for_sale  825000.0  5.0   5.0      0.79
# 923158  for_sale   88000.0  NaN   NaN     35.00
#
#                                              full_address  \
# 0       Sector Yahuecas Titulo # V84, Adjuntas, PR, 00601
# 1                 Km 78 9 Carr # 135, Adjuntas, PR, 00601
# 2                 556G 556-G 16 St, Juana Diaz, PR, 00795
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce,...
# 4                         14 Navarro, Mayaguez, PR, 00680
# ...                                                   ...
# 923154                 1008 King St, Chappaqua, NY, 10514
# 923155                    3 Elmwood Dr, Monroe, NY, 10950
# 923156                13 N Conger Ave, Congers, NY, 10920
# 923157             7 Miller Rd, Valley Cottage, NY, 10989
# 923158  D18 Half Moon Bay Dr, Croton On Hudson, NY, 10520
#
#                                                street              city  \
# 0                        Sector Yahuecas Titulo # V84          Adjuntas
# 1                                  Km 78 9 Carr # 135          Adjuntas
# 2                                    556G 556-G 16 St        Juana Diaz
# 3       R5 Comunidad El Paraso Calle De Oro R-5 Ponce             Ponce
# 4                                          14 Navarro          Mayaguez
# ...                                               ...               ...
# 923154                                   1008 King St         Chappaqua
# 923155                                   3 Elmwood Dr            Monroe
# 923156                                13 N Conger Ave           Congers
# 923157                                    7 Miller Rd    Valley Cottage
# 923158                           D18 Half Moon Bay Dr  Croton On Hudson
#
#               state  zip_code  house_size   sold_date
# 0       Puerto Rico     601.0       920.0         NaN
# 1       Puerto Rico     601.0      1527.0         NaN
# 2       Puerto Rico     795.0       748.0         NaN
# 3       Puerto Rico     731.0      1800.0         NaN
# 4       Puerto Rico     680.0         NaN         NaN
# ...             ...       ...         ...         ...
# 923154     New York   10514.0      1052.0  2011-05-09
# 923155     New York   10950.0      1650.0  2015-07-21
# 923156     New York   10920.0      2123.0         NaN
# 923157     New York   10989.0      3775.0  2010-06-02
# 923158     New York   10520.0       780.0         NaN
#
# [923159 rows x 12 columns]

# %%
# drop unnecessary columns
housing_df = housing_df.drop(housing_df.columns[[5,6,]], axis=1)

# %%
housing_df = housing_df.loc[
                        (housing_df["state"] == "New York")]

# %%
housing_df = housing_df.loc[
                        (housing_df["city"] == "Mount Vernon") |
                        (housing_df["city"] == "New Rochelle") |
                        (housing_df["city"] == "Nyack") |
                        (housing_df["city"] == "Tuckahoe") |
                        (housing_df["city"] == "Suffern") |
                        (housing_df["city"] == "Warwick") |
                        (housing_df["city"] == "Stony Point") |
                        (housing_df["city"] == "Scarsdale") |
                        (housing_df["city"] == "Brooklyn") |
                        (housing_df["city"] == "Bronx") |
                        (housing_df["city"] == "Staten Island") |
                        (housing_df["city"] == "Queens") |
                        (housing_df["city"] == "Manhattan")]
housing_df
# Out:
#           status      price  bed  bath  acre_lot         city     state  \
# 465079  for_sale  1575000.0  3.0   2.0     20.00     Brooklyn  New York
# 465080  for_sale   899000.0  NaN   NaN      0.07        Bronx  New York
# 465081  for_sale   890000.0  7.0   3.0      0.10        Bronx  New York
# 465090  for_sale   344900.0  2.0   1.0       NaN        Bronx  New York
# 465095  for_sale  1500000.0  8.0   3.0      0.04     Brooklyn  New York
# ...          ...        ...  ...   ...       ...          ...       ...
# 923036  for_sale   579000.0  3.0   3.0      0.05      Suffern  New York
# 923061  for_sale  3475000.0  6.0   8.0      0.78    Scarsdale  New York
# 923084  for_sale   549000.0  5.0   2.0      0.09        Nyack  New York
# 923110  for_sale  1200000.0  4.0   3.0      5.20  Stony Point  New York
# 923137  for_sale   289000.0  2.0   1.0       NaN    Scarsdale  New York
#
#         zip_code  house_size   sold_date
# 465079   11225.0      2400.0  1987-11-27
# 465080   10466.0      1880.0  1985-05-29
# 465081   10468.0      2824.0  1996-03-08
# 465090   10463.0      1000.0  2006-11-22
# 465095   11221.0      2700.0  2010-02-22
# ...          ...         ...         ...
# 923036   10901.0      2164.0  2007-03-30
# 923061   10583.0      8137.0  2012-03-27
# 923084   10960.0      2870.0         NaN
# 923110   10980.0      2800.0  2021-01-08
# 923137   10583.0      1100.0         NaN
#
# [53515 rows x 10 columns]

# %%
# keep only dates jan 2019 - dec 2021
housing_df = housing_df[
                    (housing_df["sold_date"] >= "2019-01-01") & 
                    (housing_df["sold_date"] <= "2021-12-31")]
housing_df
# Out:
#           status      price  bed  bath  acre_lot         city     state  \
# 465601  for_sale   785000.0  1.0   1.0       NaN    Manhattan  New York
# 465708  for_sale   959000.0  8.0   4.0      0.07        Bronx  New York
# 465785  for_sale  2125000.0  2.0   3.0       NaN     Brooklyn  New York
# 465849  for_sale   899000.0  2.0   1.0       NaN    Manhattan  New York
# 465906  for_sale   785000.0  3.0   2.0       NaN       Queens  New York
# ...          ...        ...  ...   ...       ...          ...       ...
# 922663  for_sale   750000.0  4.0   3.0      0.05     Tuckahoe  New York
# 922810  for_sale   799000.0  5.0   4.0      0.63      Suffern  New York
# 922964  for_sale  3700000.0  6.0   8.0      0.67    Scarsdale  New York
# 922968  for_sale   799000.0  4.0   2.0      0.19     Tuckahoe  New York
# 923110  for_sale  1200000.0  4.0   3.0      5.20  Stony Point  New York
#
#         zip_code  house_size   sold_date
# 465601   10022.0         NaN  2020-02-19
# 465708   10466.0         NaN  2019-01-09
# 465785   11238.0      2150.0  2019-10-09
# 465849   10022.0         NaN  2019-07-17
# 465906   11385.0      1400.0  2021-09-01
# ...          ...         ...         ...
# 922663   10707.0      2065.0  2019-07-05
# 922810   10901.0      3750.0  2021-05-26
# 922964   10583.0      8048.0  2020-08-26
# 922968   10707.0      2224.0  2019-11-21
# 923110   10980.0      2800.0  2021-01-08
#
# [3401 rows x 10 columns]

# %%
# drop rows with null values
housing_df = housing_df.dropna()
housing_df
# Out:
#           status      price  bed  bath  acre_lot         city     state  \
# 466030  for_sale   979000.0  8.0   5.0      0.04        Bronx  New York
# 466364  for_sale   937500.0  4.0   3.0      0.06        Bronx  New York
# 466770  for_sale   879000.0  7.0   4.0      0.05        Bronx  New York
# 467315  for_sale   589000.0  3.0   2.0      0.05        Bronx  New York
# 467471  for_sale   800000.0  4.0   2.0      0.05     Brooklyn  New York
# ...          ...        ...  ...   ...       ...          ...       ...
# 922663  for_sale   750000.0  4.0   3.0      0.05     Tuckahoe  New York
# 922810  for_sale   799000.0  5.0   4.0      0.63      Suffern  New York
# 922964  for_sale  3700000.0  6.0   8.0      0.67    Scarsdale  New York
# 922968  for_sale   799000.0  4.0   2.0      0.19     Tuckahoe  New York
# 923110  for_sale  1200000.0  4.0   3.0      5.20  Stony Point  New York
#
#         zip_code  house_size   sold_date
# 466030   10467.0      3297.0  2019-01-24
# 466364   10472.0      2585.0  2019-08-26
# 466770   10458.0      3374.0  2020-10-23
# 467315   10469.0      1664.0  2021-02-01
# 467471   11207.0      2880.0  2019-12-23
# ...          ...         ...         ...
# 922663   10707.0      2065.0  2019-07-05
# 922810   10901.0      3750.0  2021-05-26
# 922964   10583.0      8048.0  2020-08-26
# 922968   10707.0      2224.0  2019-11-21
# 923110   10980.0      2800.0  2021-01-08
#
# [1201 rows x 10 columns]

# %%
housing_df.dtypes
# Out:
# status         object
# price         float64
# bed           float64
# bath          float64
# acre_lot      float64
# city           object
# state          object
# zip_code      float64
# house_size    float64
# sold_date      object
# dtype: object

# %% [markdown]
# ## Export Data to PostgreSQL Database

# %%
# export dataframes to perform sql join to add populations to housing dataframes
urban_population_df.to_sql(name="urban_populations", con=engine)
city_population_df.to_sql(name="city_populations", con=engine)
housing_df.to_sql(name="housing", con=engine)
